# %%
from my_weapon import *
from SQLite_handler import *
sns.set(style="darkgrid", font_scale=1.5)

# %%
data = pd.read_csv("disk/results-14days.csv").set_index("dt")
data = data.rename(columns={"0": "Pete Buttigieg", 
                            "1": "Bernie Sanders", 
                            "2": "Elizabeth Warren", 
                            "3": "Joe Biden", 
                            "4": "Others",})
data.to_csv("data/csv/results-14days.csv")

data_p = data.div(data.sum(axis=1), axis=0) * 100
data_p = data_p.round(3)
data_p.to_csv("data/csv/results-14days-percent.csv")

# %%
data = pd.read_csv("disk/results-culFrom09.csv").set_index("dt")
data = data.rename(columns={"0": "Pete Buttigieg", 
                            "1": "Bernie Sanders", 
                            "2": "Elizabeth Warren", 
                            "3": "Joe Biden", 
                            "4": "Others",})
data.to_csv("data/csv/results-culFrom09.csv")

data_p = data.div(data.sum(axis=1), axis=0) * 100
data_p = data_p.round(3)
data_p.to_csv("data/csv/results-culFrom09-percent.csv")

# %%
data = pd.read_csv("disk/results-culFrom11.csv").set_index("dt")
data = data.rename(columns={"0": "Pete Buttigieg", 
                            "1": "Bernie Sanders", 
                            "2": "Elizabeth Warren", 
                            "3": "Joe Biden", 
                            "4": "Others",})
data.to_csv("data/csv/results-culFrom11.csv")

data_p = data.div(data.sum(axis=1), axis=0) * 100
data_p = data_p.round(3)
data_p.to_csv("data/csv/results-culFrom11-percent.csv")

# %%
data = pd.read_csv("disk/results-culFrom01.csv").set_index("dt")
data = data.rename(columns={"0": "Pete Buttigieg", 
                            "1": "Bernie Sanders", 
                            "2": "Elizabeth Warren", 
                            "3": "Joe Biden", 
                            "4": "Others",})
data.to_csv("data/csv/results-culFrom01.csv")

data_p = data.div(data.sum(axis=1), axis=0) * 100
data_p = data_p.round(3)
data_p.to_csv("data/csv/results-culFrom01-percent.csv")

# %%
# for states

data = pd.read_csv("disk/results-culFrom01-0219-in-states.csv").set_index("state")
data = data.rename(columns={"0": "Pete Buttigieg", 
                            "1": "Bernie Sanders", 
                            "2": "Elizabeth Warren", 
                            "3": "Joe Biden", 
                            "4": "Others",})
data.to_csv("data/csv/results-culFrom01-0219-in-states.csv")

data_p = data.div(data.sum(axis=1), axis=0) * 100
data_p = data_p.round(3)
data_p.to_csv("data/csv/results-culFrom01-0219-in-states-percent.csv")

data = pd.read_csv("disk/results-culFrom09-0219-in-states.csv").set_index("state")
data = data.rename(columns={"0": "Pete Buttigieg", 
                            "1": "Bernie Sanders", 
                            "2": "Elizabeth Warren", 
                            "3": "Joe Biden", 
                            "4": "Others",})
data.to_csv("data/csv/results-culFrom09-0219-in-states.csv")

data_p = data.div(data.sum(axis=1), axis=0) * 100
data_p = data_p.round(3)
data_p.to_csv("data/csv/results-culFrom09-0219-in-states-percent.csv")

data = pd.read_csv("disk/results-culFrom11-0219-in-states.csv").set_index("state")
data = data.rename(columns={"0": "Pete Buttigieg", 
                            "1": "Bernie Sanders", 
                            "2": "Elizabeth Warren", 
                            "3": "Joe Biden", 
                            "4": "Others",})
data.to_csv("data/csv/results-culFrom11-0219-in-states.csv")

data_p = data.div(data.sum(axis=1), axis=0) * 100
data_p = data_p.round(3)
data_p.to_csv("data/csv/results-culFrom11-0219-in-states-percent.csv")

# %%
sns.set(style="dark", font_scale=1.5)
# plt.style.use('fivethirtyeight')

data_p = pd.read_csv("data/csv/results-culFrom01-0219-in-states-percent.csv").set_index("state")
data_p = data_p.sort_index()
# data_p[data_p.state=="NY"].plot.bar()
data_p.plot(kind='bar',stacked = True, figsize=(25,10))
plt.xticks(rotation=45)
plt.xlabel("")
plt.ylabel("Percent")
# plt.legend(loc=4, bbox_to_anchor=(0.9, -0.05, 0.25, 0.25))
plt.legend(loc=4, bbox_to_anchor=(0.75, 1), ncol=5, frameon=False)
plt.savefig("fig/culFrom01-0219-in-states-percent.png", dpi=300, bbox_inches ='tight')
plt.show()

# %%
sns.set(style="dark", font_scale=1.5)
# plt.style.use('fivethirtyeight')

data_p = pd.read_csv("data/csv/results-culFrom11-0219-in-states-percent.csv").set_index("state")
data_p = data_p.sort_index()
data_p.plot(kind='bar',stacked = True, figsize=(25,10))
plt.xticks(rotation=45)
plt.xlabel("")
plt.ylabel("Percent")
# plt.legend(loc=4, bbox_to_anchor=(0.9, -0.05, 0.25, 0.25))
plt.legend(loc=4, bbox_to_anchor=(0.75, 1), ncol=5, frameon=False)
plt.savefig("fig/culFrom11-0219-in-states-percent.png", dpi=300, bbox_inches ='tight')
plt.show()

# %%
sns.set(style="dark", font_scale=1.5)

data_p = pd.read_csv("data/csv/results-culFrom09-0219-in-states-percent.csv").set_index("state")
data_p = data_p.sort_index()
data_p.plot(kind='bar',stacked = True, figsize=(25,10))
plt.xticks(rotation=45)
plt.xlabel("")
plt.ylabel("Percent")
# plt.legend(loc=4, bbox_to_anchor=(0.9, -0.05, 0.25, 0.25))
plt.legend(loc=4, bbox_to_anchor=(0.75, 1), ncol=5, frameon=False)
plt.savefig("fig/culFrom09-0219-in-states-percent.png", dpi=300, bbox_inches ='tight')
plt.show()

# %%
sns.set(style="darkgrid", font_scale=1.5)

US_states = [line.strip() for line in open("data/states_short_name.txt")]
data = pd.read_csv("data/csv/results-culFrom09-0219-in-states-percent.csv").set_index("state")

for _s in tqdm(US_states):
    data_p = data[data.index==_s]
    data_p.plot(kind='bar', width=0.8)
    plt.xticks(rotation=45)
    plt.xlabel("")
    plt.ylabel("Percent")
    plt.legend(loc=4, bbox_to_anchor=(1.3, 0, 0.25, 0.25))
    # plt.legend(loc=4, bbox_to_anchor=(0.75, 1), ncol=5, frameon=False)
    plt.savefig(f"fig/culFrom09-0219-in-{_s}.png", dpi=300, bbox_inches ='tight')
    plt.close()
    # plt.show()
    
data = pd.read_csv("data/csv/results-culFrom01-0219-in-states-percent.csv").set_index("state")

for _s in tqdm(US_states):
    data_p = data[data.index==_s]
    data_p.plot(kind='bar', width=0.8)
    plt.xticks(rotation=45)
    plt.xlabel("")
    plt.ylabel("Percent")
    plt.legend(loc=4, bbox_to_anchor=(1.3, 0, 0.25, 0.25))
    # plt.legend(loc=4, bbox_to_anchor=(0.75, 1), ncol=5, frameon=False)
    plt.savefig(f"fig/culFrom01-0219-in-{_s}.png", dpi=300, bbox_inches ='tight')
    plt.close()
    # plt.show()
# Out:
# ...
# 100%|██████████| 51/51 [00:15<00:00,  3.26it/s]

# %%
sns.set(style="darkgrid", font_scale=1.5)

US_states = [line.strip() for line in open("data/states_short_name.txt")]
data = pd.read_csv("data/csv/results-culFrom09-0219-in-states-percent.csv").set_index("state")

for _s in tqdm(US_states):
    data_p = data[data.index==_s]
    data_p.plot(kind='bar', width=0.8)
    plt.xticks(rotation=45)
    plt.xlabel("")
    plt.ylabel("Percent")
    plt.legend(loc=4, bbox_to_anchor=(1.3, 0, 0.25, 0.25))
    # plt.legend(loc=4, bbox_to_anchor=(0.75, 1), ncol=5, frameon=False)
    plt.savefig(f"fig/culFrom09-0219-in-{_s}.png", dpi=300, bbox_inches ='tight')
    plt.close()
    # plt.show()
    
data = pd.read_csv("data/csv/results-culFrom01-0219-in-states-percent.csv").set_index("state")

for _s in tqdm(US_states):
    data_p = data[data.index==_s]
    data_p.plot(kind='bar', width=0.8)
    plt.xticks(rotation=45)
    plt.xlabel("")
    plt.ylabel("Percent")
    plt.legend(loc=4, bbox_to_anchor=(1.3, 0, 0.25, 0.25))
    # plt.legend(loc=4, bbox_to_anchor=(0.75, 1), ncol=5, frameon=False)
    plt.savefig(f"fig/culFrom01-0219-in-{_s}.png", dpi=300, bbox_inches ='tight')
    plt.close()
    # plt.show()

# %%
sns.set(style="darkgrid", font_scale=1.5)

def plot_state(csv_file):
    state = csv_file.split("-")[-1][:2]
    print(state)
    data = pd.read_csv("disk/" + csv_file).set_index("state")
    data = data.rename(columns={"0": "Pete Buttigieg", 
                                "1": "Bernie Sanders", 
                                "2": "Elizabeth Warren", 
                                "3": "Joe Biden", 
                                "4": "Others"})
    data_p = data.div(data.sum(axis=1), axis=0) * 100
    data_p = data_p[data_p.index==state]

    data_p.plot(kind='bar', width=0.8)
    plt.xticks(rotation=45)
    plt.xlabel("")
    plt.ylabel("Percent")
    plt.legend(loc=4, bbox_to_anchor=(1.35, 0, 0.25, 0.25))
    # plt.legend(loc=4, bbox_to_anchor=(0.75, 1), ncol=5, frameon=False)
    plt.savefig(f"fig/{csv_file}.png", dpi=300, bbox_inches ='tight')
    # plt.close()
    plt.show()

csv_file = "results-14days-0203-IADay.csv"
plot_state(csv_file)
csv_file = "results-14days-0211-NHDay.csv"
plot_state(csv_file)
csv_file = "results-14days-0222-NVDay.csv"
plot_state(csv_file)

csv_file = "results-culFrom01-0203-IADay.csv"
plot_state(csv_file)
csv_file = "results-culFrom01-0211-NHDay.csv"
plot_state(csv_file)
csv_file = "results-culFrom01-0222-NVDay.csv"
plot_state(csv_file)
# Out:
# IA
# NH
# NV
# IA
# NH
# NV

# %%
# d3.to_csv("web/data/positive-raw-all.csv")
d3.to_csv("web/data/positive-all.csv")

# %%
d3 = d3[d3.index >= "2019-03-01"]

# %%
# d3.to_csv("web/data/positive-raw.csv")
d3.to_csv("web/data/positive.csv")

# %%
_sum = d2["Cristina (Elypsis)"] + d2["Macri (Elypsis)"] 
d2["Cristina (Elypsis)"] = d2["Cristina (Elypsis)"] / _sum
d2["Macri (Elypsis)"] = d2["Macri (Elypsis)"] / _sum

# %%
d2
# Out:
#             Cristina (Elypsis)  Macri (Elypsis)
# dt
# 2016-05-16            0.457447         0.542553
# 2016-05-23            0.409091         0.590909
# 2016-05-30            0.448980         0.551020
# 2016-06-06            0.531915         0.468085
# 2016-06-13            0.400000         0.600000
# 2016-06-20            0.494382         0.505618
# 2016-06-27            0.428571         0.571429
# 2016-07-04            0.439024         0.560976
# 2016-07-11            0.443182         0.556818
# 2016-07-18            0.432990         0.567010
# 2016-07-25            0.471910         0.528090
# 2016-08-01            0.436782         0.563218
# 2016-08-08            0.434783         0.565217
# 2016-08-15            0.425287         0.574713
# 2016-08-22            0.483146         0.516854
# 2016-08-29            0.451220         0.548780
# 2016-09-05            0.448718         0.551282
# 2016-09-12            0.462366         0.537634
# ...

# %%
new_data = [
("2019-06-02", {'K': 627374, 'M': 616194, 'U': 104453, 'irrelevant': 556245}),
("2019-06-03", {'K': 629048, 'M': 615248, 'U': 104199, 'irrelevant': 562930}),
("2019-06-04", {'K': 633154, 'M': 616789, 'U': 104473, 'irrelevant': 572342}),
("2019-06-05", {'K': 638056, 'M': 607881, 'U': 103328, 'irrelevant': 586891}),
("2019-06-06", {'K': 653290, 'M': 594586, 'U': 102956, 'irrelevant': 598743}),
("2019-06-07", {'K': 660631, 'M': 576642, 'U': 100658, 'irrelevant': 605207}),
("2019-06-08", {'K': 673992, 'M': 562559, 'U': 99555, 'irrelevant': 602822}),
("2019-06-09", {'K': 668222, 'M': 556018, 'U': 97460, 'irrelevant': 592681}),
("2019-06-10", {'K': 669108, 'M': 536727, 'U': 94222, 'irrelevant': 576124}),
("2019-06-11", {'K': 672085, 'M': 508925, 'U': 90419, 'irrelevant': 565035}),
("2019-06-12", {'K': 677464, 'M': 497816, 'U': 91929, 'irrelevant': 565399}),
]

# %%
new_data
# Out:
# [('2019-06-02', {'K': 627374, 'M': 616194, 'U': 104453, 'irrelevant': 556245}),
#  ('2019-06-03', {'K': 629048, 'M': 615248, 'U': 104199, 'irrelevant': 562930}),
#  ('2019-06-04', {'K': 633154, 'M': 616789, 'U': 104473, 'irrelevant': 572342}),
#  ('2019-06-05', {'K': 638056, 'M': 607881, 'U': 103328, 'irrelevant': 586891}),
#  ('2019-06-06', {'K': 653290, 'M': 594586, 'U': 102956, 'irrelevant': 598743}),
#  ('2019-06-07', {'K': 660631, 'M': 576642, 'U': 100658, 'irrelevant': 605207}),
#  ('2019-06-08', {'K': 673992, 'M': 562559, 'U': 99555, 'irrelevant': 602822}),
#  ('2019-06-09', {'K': 668222, 'M': 556018, 'U': 97460, 'irrelevant': 592681}),
#  ('2019-06-10', {'K': 669108, 'M': 536727, 'U': 94222, 'irrelevant': 576124}),
#  ('2019-06-11', {'K': 672085, 'M': 508925, 'U': 90419, 'irrelevant': 565035}),
#  ('2019-06-12', {'K': 677464, 'M': 497816, 'U': 91929, 'irrelevant': 565399})]

# %%
import pendulum

# %%
new_data = [Weekly_Predict(dt=pendulum.parse(r[0]),
                           U_Cristina=r[1]['K'], U_Macri=r[1]['M'], U_unclassified=r[1]['U'], U_irrelevant=r[1]['irrelevant']) for r in new_data]

# %%
new_data

# %%
sess = get_session()
sess.add_all(new_data)
sess.commit()
sess.close()

# %%
sess = get_session()
tweets_db_to_hashtags75_lastweek(sess, end=pendulum.today(tz="UTC"))
sess.close()
# Out:
# 64039it [00:17, 3580.97it/s]
# 60678it [00:15, 3975.20it/s]
# 58380it [00:10, 5389.44it/s]
# 50479it [00:10, 4836.71it/s]
# 53964it [00:10, 5282.30it/s]
# 72417it [00:07, 9219.04it/s]
# 92171it [00:02, 41426.46it/s]
# 0it [00:00, ?it/s]
# 31950
# clear Last_Week_Hashtag75 ...

# %%
d = pd.read_csv("web/data/2019-05-14/day7.csv").set_index("dt")
d.index = pd.to_datetime(d.index)
AI = d[["Cristina (AI)", "Macri (AI)"]].dropna(axis=0, how='all')
AI = AI[AI.index.dayofweek == 0]

# %%
d = pd.read_csv("web/data/2019-05-14/positive.csv").set_index("dt")
d.index = pd.to_datetime(d.index)
# AI = d[["Cristina (AI)", "Macri (AI)"]].dropna(axis=0, how='all')
# AI = AI[AI.index.dayofweek == 0]
EL = d[["Cristina (Elypsis)", "Macri (Elypsis)"]].dropna(axis=0, how='all')
# d

# %%
# format your data to desired format. Here I chose YYYY-MM-DD but you can set it to whatever you want.
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)

ax.plot(AI["Macri (AI)"], lw=4, label="AI")
# ax.plot(d2["Macri (Elypsis)"], label="E1")
# ax.plot(d3["Macri (Elypsis)"], label="E2")
ax.plot(EL["Macri (Elypsis)"], label="E3")
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%m'))
ax.legend()

# %%
d1 = (AI.pct_change()[1:] * 100).round(2)
d1 = d1[["Macri (AI)"]]
d2 = (EL.pct_change()[1:] * 100).round(2)
d2["Elypsis (no lag)"] = d2["Macri (Elypsis)"]
d2 = d2[["Elypsis (no lag)"]]
d3 = d2.shift(1).dropna()
d3["Elypsis (7-days in advance)"] = d3["Elypsis (no lag)"]
d3 = d3[["Elypsis (7-days in advance)"]]
d4 = d2.shift(2).dropna()
d4["Elypsis (14-days in advance)"] = d4["Elypsis (no lag)"]
d4 = d4[["Elypsis (14-days in advance)"]]

d1 = d1.append(d3).append(d4)
d1 = d1[["Macri (AI)", "Elypsis (7-days in advance)", "Elypsis (14-days in advance)"]]

# %%
d1.to_csv("web/data/2019-05-14/lag7.csv")

# %%
# format your data to desired format. Here I chose YYYY-MM-DD but you can set it to whatever you want.
import matplotlib.dates as mdates

d1.plot()

# %%
d1
# Out:
#             Cristina (AI)  Macri (AI)
# dt
# 2019-03-11           6.56       -7.05
# 2019-03-18           5.25       -6.47
# 2019-03-25           0.52       -0.72
# 2019-04-01          -9.76       13.70
# 2019-04-08           9.87      -10.99
# 2019-04-15          -7.77       10.69
# 2019-04-22          -4.68        5.36
# 2019-04-29          -1.57        1.63
# 2019-05-13          13.57      -13.63
# 2019-05-20          -7.56        9.98
# 2019-05-27          -1.71        1.90
# 2019-06-03          -2.13        2.28
# 2019-06-10           7.91       -8.10
# 2019-06-17          -2.75        3.30

# %%
d = pd.read_csv("web/data/2019-05-14/day1.csv").set_index("dt")

# d["3-days"] = d["Macri (AI)"].rolling(3).mean()
d["7-days"] = d["Macri (AI)"].rolling(7).mean()
d["14-days"] = d["Macri (AI)"].rolling(14).mean()
d["30-days"] = d["Macri (AI)"].rolling(30).mean()
# d["60-days"] = d["Macri (AI)"].rolling(60).mean()
d = d.drop("Cristina (AI)", axis=1)

d["Macri (AI)"].rolling(1).mean().dropna()[0]

for i in range(30):
    if np.isnan(d.iloc[i, 1]): 
        d.iloc[i, 1] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
    if np.isnan(d.iloc[i, 2]): 
        d.iloc[i, 2] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
    if np.isnan(d.iloc[i, 3]):
        d.iloc[i, 3] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
        
d = d.round(3)
d.to_csv("web/data/2019-05-14/ma1.csv")
d
# Out:
#             Macri (AI)  7-days  14-days  30-days
# dt
# 2019-03-01       0.514   0.514    0.514    0.514
# 2019-03-02       0.518   0.516    0.516    0.516
# 2019-03-03       0.625   0.552    0.552    0.552
# 2019-03-04       0.527   0.546    0.546    0.546
# 2019-03-05       0.448   0.526    0.526    0.526
# 2019-03-06       0.481   0.519    0.519    0.519
# 2019-03-07       0.466   0.511    0.511    0.511
# 2019-03-08       0.464   0.504    0.505    0.505
# 2019-03-09       0.498   0.501    0.505    0.505
# 2019-03-10       0.539   0.489    0.508    0.508
# 2019-03-11       0.540   0.491    0.511    0.511
# 2019-03-12       0.520   0.501    0.512    0.512
# 2019-03-13       0.482   0.501    0.509    0.509
# 2019-03-14       0.352   0.485    0.498    0.498
# 2019-03-15       0.407   0.477    0.491    0.492
# 2019-03-16       0.438   0.468    0.485    0.489
# 2019-03-17       0.500   0.463    0.476    0.489
# 2019-03-18       0.448   0.450    0.470    0.487
# ...

# %%
d = pd.read_csv("web/data/2019-05-14/day3.csv").set_index("dt")

# d["3-days"] = d["Macri (AI)"].rolling(3).mean()
d["7-days"] = d["Macri (AI)"].rolling(7).mean()
d["14-days"] = d["Macri (AI)"].rolling(14).mean()
d["30-days"] = d["Macri (AI)"].rolling(30).mean()
# d["60-days"] = d["Macri (AI)"].rolling(60).mean()
d = d.drop("Cristina (AI)", axis=1)

d["Macri (AI)"].rolling(1).mean().dropna()[0]

for i in range(30):
    if np.isnan(d.iloc[i, 1]): 
        d.iloc[i, 1] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
    if np.isnan(d.iloc[i, 2]): 
        d.iloc[i, 2] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
    if np.isnan(d.iloc[i, 3]):
        d.iloc[i, 3] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
        
d = d.round(3)
d.to_csv("web/data/2019-05-14/ma3.csv")

# %%
d = pd.read_csv("web/data/2019-05-14/day7.csv").set_index("dt")

# d["3-days"] = d["Macri (AI)"].rolling(3).mean()
d["7-days"] = d["Macri (AI)"].rolling(7).mean()
d["14-days"] = d["Macri (AI)"].rolling(14).mean()
d["30-days"] = d["Macri (AI)"].rolling(30).mean()
# d["60-days"] = d["Macri (AI)"].rolling(60).mean()
d = d.drop("Cristina (AI)", axis=1)

d["Macri (AI)"].rolling(1).mean().dropna()[0]

for i in range(30):
    if np.isnan(d.iloc[i, 1]): 
        d.iloc[i, 1] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
    if np.isnan(d.iloc[i, 2]): 
        d.iloc[i, 2] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
    if np.isnan(d.iloc[i, 3]):
        d.iloc[i, 3] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
        
d = d.round(3)
d.to_csv("web/data/2019-05-14/ma7.csv")

# %%
d = pd.read_csv("web/data/2019-05-14/day14.csv").set_index("dt")

# d["3-days"] = d["Macri (AI)"].rolling(3).mean()
d["7-days"] = d["Macri (AI)"].rolling(7).mean()
d["14-days"] = d["Macri (AI)"].rolling(14).mean()
d["30-days"] = d["Macri (AI)"].rolling(30).mean()
# d["60-days"] = d["Macri (AI)"].rolling(60).mean()
d = d.drop("Cristina (AI)", axis=1)

d["Macri (AI)"].rolling(1).mean().dropna()[0]

for i in range(30):
    if np.isnan(d.iloc[i, 1]): 
        d.iloc[i, 1] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
    if np.isnan(d.iloc[i, 2]): 
        d.iloc[i, 2] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
    if np.isnan(d.iloc[i, 3]):
        d.iloc[i, 3] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
        
d = d.round(3)
d.to_csv("web/data/2019-05-14/ma14.csv")

# %%
d = pd.read_csv("web/data/2019-05-14/day30.csv").set_index("dt")

# d["3-days"] = d["Macri (AI)"].rolling(3).mean()
d["7-days"] = d["Macri (AI)"].rolling(7).mean()
d["14-days"] = d["Macri (AI)"].rolling(14).mean()
d["30-days"] = d["Macri (AI)"].rolling(30).mean()
# d["60-days"] = d["Macri (AI)"].rolling(60).mean()
d = d.drop("Cristina (AI)", axis=1)

d["Macri (AI)"].rolling(1).mean().dropna()[0]

for i in range(30):
    if np.isnan(d.iloc[i, 1]): 
        d.iloc[i, 1] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
    if np.isnan(d.iloc[i, 2]): 
        d.iloc[i, 2] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
    if np.isnan(d.iloc[i, 3]):
        d.iloc[i, 3] = d["Macri (AI)"].rolling(i+1).mean().dropna()[0]
        
d = d.round(3)
d.to_csv("web/data/2019-05-14/ma30.csv")

# %%
# plt.figure(figsize=(12, 6))
d.plot()

# %%
d = pd.read_csv("web/data/2019-05-14/p2.csv").set_index("dt")

# %%
d["Cristina (AI)"] = d["Cristina (AI)"] * 1.5
d["Macri (AI)"] = d["Macri (AI)"] * 1.5
d.to_csv("data/22222.txt")
